# %% [markdown]
# Creating a DataFrame

# %%
import numpy as np 
import pandas as pd

# %%
data={
    'Name':['John','Anna','Peter','Linda'],
    'Age':[28,34,29,42],
    'City':['New York','Paris','Berlin','London'],
    'Salary':[65000,70000,62000,85000]
}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_List=[
['Jhon',28,'New York',65000],
['Anna',34,'Paris',70000],
['Peter',29,'Berlin',62000],
['Linda',42,'London',85000]
]
df2=pd.DataFrame(data_List)
df2
# Out:
#        0   1         2      3
# 0   Jhon  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
columns = ["Name","Age","City","Salary"]
df3 = pd.DataFrame(data_List,columns=columns)
df3
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3['Name']
# Out:
# 0     Jhon
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df3[['Name','City']]
# Out:
#     Name      City
# 0   Jhon  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating New Columns

# %%
df3["Designaton"]=['HR',"CEO",'CTO','Manager']

# %%
df3
# Out:
#     Name  Age      City  Salary Designaton
# 0   Jhon   28  New York   65000         HR
# 1   Anna   34     Paris   70000        CEO
# 2  Peter   29    Berlin   62000        CTO
# 3  Linda   42    London   85000    Manager

# %% [markdown]
# Removing Column

# %%
df3.drop("Designaton",axis=1)
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3
# Out:
#     Name  Age      City  Salary Designaton
# 0   Jhon   28  New York   65000         HR
# 1   Anna   34     Paris   70000        CEO
# 2  Peter   29    Berlin   62000        CTO
# 3  Linda   42    London   85000    Manager

# %%
df3.drop("Designaton",axis=1,inplace=True)

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# Selecting Rows

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df3.loc[[0,1]]
# Out:
#    Name  Age      City  Salary
# 0  Jhon   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   Jhon   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#Those people Whose Age is Aabove 30
df3[df3['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
# Those People Whose age is above 30 and Their city must be Paris
df3[(df3['Age']>30) & (df3['City']=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
